# %%
from Bio.PDB import PDBParser
from pymol import cmd
import os
import pandas as pd
from tqdm  import tqdm

# %%
a=[]
for i in range(20):
    a.append(pd.read_csv(f'/home/adamczykb/rnaquanet/data/00_reference/lociparse_train/train_f_{i}.csv'))

# %%
b=[]
for i in range(20):
    b.append(pd.read_csv(f'/home/adamczykb/rnaquanet/data/00_reference/lociparse_train/val_f_{i}.csv'))

# %%
final = pd.read_csv(f'/home/adamczykb/rnaquanet/data/00_reference/lociparse_train/train.csv')

# %%
final.loc[final['RMSD']<=15.,:]
# Out:
#               id                                           sequence  length  \
# 0      1EUY_1_33  GGGGUAUCGCCAAGCGGUAAGGCACCGGAUUCUGAUUCCGGCAAGC...      73
# 1      1AJU_1_26                     GGCCAGAUUGAGCCUGGGAGCUCUCUGGCC      30
# 2      1F5U_1_12                                 GGUGGGAGACGUCCCACC      18
# 3      1EKZ_1_12                     GGACAGCUGUCCCUUCGGGGACAGCUGUCC      30
# 4      1ELH_1_11                                       UUGCCUGGCGGC      12
# ...          ...                                                ...     ...
# 41331   7A3Y_2_5                                       CAGGAUAGCUGC      12
# 41332  7CYQ_1_27                        UGACUGCUCCCUAGCAUGCUACUACCG      27
# 41333  7JL0_2_13                                     UCAGUCAGUCAGUC      14
# 41334   7NWG_2_9  GUCUCCGUAGUGUAGGGUAUCACGUUCGCCUAACACGCGAAAGGUC...      74
# 41335  6qx9_1_36  AUACUUACCUGGCAGGGGAGAUACCAUGAUCACGAAGGUGGUUUUC...     164
#
# ...

# %%
final_v = pd.read_csv(f'/home/adamczykb/rnaquanet/data/00_reference/lociparse_train/val_f.csv')

# %%
pd.concat(b, ignore_index=True).to_csv(f'')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.concat(b, ignore_index=True).to_csv(f'/home/adamczykb/rnaquanet/data/01_reference/lociparse_train/train.csv')
#
# NameError: name 'pd' is not defined

# %%
# a=pd.read_csv('/home/adamczykb/rnaquanet/data/01_raw/lociparse_structures/train.csv')
# a.columns[:-1]
# a.loc[:,a.columns[:-1]].to_csv('/home/adamczykb/rnaquanet/data/01_raw/lociparse_structures/train.csv')

# %%
a=pd.read_csv('/home/adamczykb/rnaquanet/data/01_raw/lociparse_structures/train.csv')
#

# %%
a.loc[a['id'].isin(['1FJE_1_4','1FEU_2_7'])]
# Out:
#       Unnamed: 0        id                sequence  length structure chain_no  \
# 2068        2068  1FJE_1_4  GGCCGAAAUCCCGAAGUAGGCC      22      1FJE        1
#
#       model common_structure ture_chain      RMSD         description
# 2068      4           1FJE_1          A  4.087117  1FJE_1_4/model.pdb
