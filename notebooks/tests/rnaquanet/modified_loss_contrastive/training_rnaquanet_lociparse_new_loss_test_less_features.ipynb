# %% [markdown]
# ### New loss test to use Bradley-Terry model

# %%
import os

os.chdir("/home/adamczykb/rnaquanet/src")
os.environ['MLFLOW_TRACKING_USERNAME']='admin'
os.environ['MLFLOW_TRACKING_PASSWORD']='TI5du9by'

# %%
from rnaquanet.dataset.RNAQuANetDataset import RNAQuANetDatasetTuplet
from rnaquanet.dataset.RNAQuANetDataset import RNAQuANetDatasetSubset

from torch_geometric import nn as gnn
import lightning as L
from torch_geometric.loader import DataLoader

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class RNAQuANet(L.LightningModule):
    def __init__(self, number_of_node_features: int, number_of_edge_features: int):
        
        super().__init__()
        self.save_hyperparameters()
        self.norm1 = gnn.BatchNorm(number_of_node_features)

        self.GATconv1 = gnn.GATv2Conv(
            number_of_node_features, number_of_node_features, heads=4, edge_dim=number_of_edge_features
        )

        self.GATconv2 = gnn.GATv2Conv(
            number_of_node_features * 4, number_of_node_features, heads=4, edge_dim=number_of_edge_features
        )
        self.GATconv3 = gnn.GATv2Conv(
            number_of_node_features * 4, number_of_node_features, heads=4, edge_dim=number_of_edge_features
        )

        self.GCN2Conv1 = gnn.GeneralConv(
            number_of_node_features * 4, number_of_node_features, in_edge_channels=number_of_edge_features
        )

        self.fc1 = nn.Linear(number_of_node_features, number_of_node_features)
        self.fc3 = nn.Linear(number_of_node_features, 1)
        self.dropout = nn.Dropout(0.3)
        self.activation = nn.LeakyReLU()
        self.activationlast = nn.ReLU()
        self.aggregation = gnn.aggr.SetTransformerAggregation(
            number_of_node_features, dropout=0.3, layer_norm=True
        )

    def forward(self, x, edge_index, edge_attr, batch):

        y = self.norm1(x)
        y = self.GATconv1(y, edge_index, edge_attr)
        y = self.activation(y)
        y = self.dropout(y)
        y = self.GATconv2(y, edge_index, edge_attr)
        y = self.activation(y)
        y = self.dropout(y)
        y = self.GATconv3(y, edge_index, edge_attr)
        y = self.activation(y)
        y = self.dropout(y)
        y = self.GCN2Conv1(y, edge_index, edge_attr)
        y = self.activation(y)
        y = self.dropout(y)

        y = self.aggregation(y, batch)

        y = self.fc1(y)
        y = self.activation(y)
        y = self.dropout(y)

        y = self.fc3(y)

        return self.activationlast(y)

    def training_step(self, data, batch_idx):
        s1, s2 = data
        result_1 = self.forward(s1.x, s1.edge_index, s1.edge_attr, s1.batch)
        result_2 = self.forward(s2.x, s2.edge_index, s2.edge_attr, s2.batch)

        loss_mae_s1 = (torch.abs(result_1 - s1.y.unsqueeze(-1))).mean()
        loss_mae_s2 = (torch.abs(result_2 - s2.y.unsqueeze(-1))).mean()
        loss_mse_s1 = (torch.square(torch.abs(result_1 - s1.y.unsqueeze(-1)))).mean()
        loss_mse_s2 = (torch.square(torch.abs(result_2 - s2.y.unsqueeze(-1)))).mean()

        self.log("train_loss_mae", (loss_mae_s1 + loss_mae_s2) / 2)
        self.log("train_loss_mse", (loss_mse_s1 + loss_mse_s2) / 2)
        loss = (loss_mae_s1 + loss_mae_s2) / 2
        result_1=result_1[0]
        result_2=result_2[0]
        if s1.y[0] < s2.y[0]:
            if result_1 > result_2:
                loss = loss + 1
        else:
            if result_1 < result_2:
                loss= loss + 1
        self.log("train_loss_mod", loss, batch_size=125)
        return loss

    def validation_step(self, data, batch_idx):
        s1, s2 = data
        result_1 = self.forward(s1.x, s1.edge_index, s1.edge_attr, s1.batch)
        result_2 = self.forward(s2.x, s2.edge_index, s2.edge_attr, s2.batch)

        loss_mae_s1 = (torch.abs(result_1 - s1.y.unsqueeze(-1))).mean()
        loss_mae_s2 = (torch.abs(result_2 - s2.y.unsqueeze(-1))).mean()
        loss_mse_s1 = (torch.square(torch.abs(result_1 - s1.y.unsqueeze(-1)))).mean()
        loss_mse_s2 = (torch.square(torch.abs(result_2 - s2.y.unsqueeze(-1)))).mean()

        self.log("val_loss_mae", (loss_mae_s1 + loss_mae_s2) / 2)
        self.log("val_loss_mse", (loss_mse_s1 + loss_mse_s2) / 2)

        loss = (loss_mae_s1 + loss_mae_s2) / 2
        result_1=result_1[0]
        result_2=result_2[0]
        if s1.y[0] < s2.y[0]:
            if result_1 > result_2:
                loss = loss + 1
        else:
            if result_1 < result_2:
                loss= loss + 1
        self.log("val_loss_mod", loss, batch_size=125)
        return loss

    def backward(self, loss):
        loss.backward()

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# %%
CUTOFF=15.0
SUBSETS=[RNAQuANetDatasetSubset.ALL]

# %%
import enum


class DATASET(enum.Enum):
    RNAQUANET = {'name':'rnaquanet','path':'rnaquanet_structures','size_of_common_identifier':3}
    ARES = {'name':'ares','path':'ares'}
    LOCIPARSE = {'name':'lociparse','path':'lociparse_structures','size_of_common_identifier':2}
    LOCIPARSE_LESS_FEATURES = {'name':'lociparse_less_features','path':'lociparse_trimmed', 'size_of_common_identifier':2}
    DECOY = {'name':'randstr_decoy','path':'randstr_decoy'}
    COMBINED = {'name':'combined','path':'combined'}

dataset_dec_train = DATASET.LOCIPARSE_LESS_FEATURES
dataset_dec_val = DATASET.LOCIPARSE_LESS_FEATURES

# %% [markdown]
# ```Error loading 1jidB_M223.pt: Ran out of input
# Error loading 1y699_M272.pt: Ran out of input
# Error loading 1xokA_M120.pt: Ran out of input
# Error loading 1ze2D_M79.pt: Ran out of input
# Error loading 3f1gZ_M97.pt: Ran out of input
# Error loading 2quxR_M241.pt: Ran out of input
# Error loading 3eogA_M482.pt: Ran out of input
# Error loading 1fg0A_M260.pt: Ran out of input
# Error loading 3gcaA_M424.pt: Ran out of input
# Error loading 2il9M_M373.pt: Ran out of input
# Error loading 2dr2B_M498.pt: Ran out of input
# Error loading 1y699_M271.pt: Ran out of input
# Error loading 2nz4S_M438.pt: Ran out of input
# Error loading 1jidB_M222.pt: Ran out of input
# Error loading 2il9M_M374.pt: Ran out of input
# Error loading 2quxR_M240.pt: Ran out of input
# Error loading 1et4E_M441.pt: Ran out of input

# %%
dataset_train = RNAQuANetDatasetTuplet(
    f"/home/adamczykb/rnaquanet/data/06_model_input/{dataset_dec_train.value['path']}/train",
    size_of_common_identifier=dataset_dec_train.value['size_of_common_identifier']
    # subsets=SUBSETS,
    # cutoff=CUTOFF,
)
dataset_val = RNAQuANetDatasetTuplet(
    f"/home/adamczykb/rnaquanet/data/06_model_input/{dataset_dec_val.value['path']}/val",
        size_of_common_identifier=dataset_dec_val.value['size_of_common_identifier']
    # subsets=SUBSETS,
    # cutoff=CUTOFF,
)
# Out:
# The dataset does not contain the 'y' tensor in the data files. Using the 'y' as RMSD.
# The dataset does not contain the 'y' tensor in the data files. Using the 'y' as RMSD.

# %%
train_loader = DataLoader(dataset_train, num_workers=24, batch_size=125, shuffle=True)
val_loader = DataLoader(dataset_val, num_workers=24, batch_size=125)

# %%
from lightning.pytorch import seed_everything
from lightning.pytorch.callbacks import RichProgressBar
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks.model_checkpoint import ModelCheckpoint
from lightning.pytorch.callbacks.progress.rich_progress import RichProgressBarTheme
from lightning.pytorch.loggers import MLFlowLogger

seed_everything(42)


class MetricTracker(L.Callback):
    def __init__(self):
        self.collection = []

    def on_validation_batch_end(self, trainer, pl_module, outputs, batch, batch_idx):
        vacc = outputs["val_loss_mae"]  # you can access them here
        self.collection.append(vacc)  # track them

    def on_validation_epoch_end(self, trainer, module):
        elogs = trainer.logged_metrics["val_loss_mae"]  # access it here
        self.collection.append(elogs)
        # do whatever is needed

model = RNAQuANet(dataset_train[0][0].x.shape[1], dataset_train[0][0].edge_attr.shape[1])

model_name = f"RNAQuANet-{dataset_dec_train.value['name']}_dataset__{'_'.join([s.value for s in SUBSETS])}_tuplet"

mlf_logger = MLFlowLogger(
    experiment_name=f"{model_name}",
    # tracking_uri="/home/adamczykb/mlflow",
    # tracking_uri="192.168.88.253:5000",
    tracking_uri="https://www.bartekadamczyk.eu/mlflow/",
    log_model="all",
)
mlf_logger.log_hyperparams(
    {
        "model_name": model_name,
        "dataset_cutoff": CUTOFF,
        "subset": {'_'.join([s.value for s in SUBSETS])},
        "dataset_size_train": len(dataset_train),
        "dataset_size_val": len(dataset_val),
        # "dataset_train_summary": dataset_train.get_summary(),
        # "dataset_val_summary": dataset_val.get_summary(),
    }
)
torch.set_float32_matmul_precision("high")
metr = MetricTracker()

# create your own theme!
progress_bar = RichProgressBar(
    theme=RichProgressBarTheme(
        metrics_text_delimiter="\n",
        metrics_format=".3e",
    )
)



model_checkpoint = ModelCheckpoint(monitor="val_loss_mae", save_top_k=1, mode="min")
trainer = L.Trainer(
    max_epochs=400,
    enable_progress_bar=True,  # callbacks=progress_bar,
    default_root_dir=f"/home/adamczykb/rnaquanet/checkpoints/{model_name}",
    # log_every_n_steps=25,
    callbacks=[
        EarlyStopping(monitor="val_loss_mae", mode="min", patience=30),
        model_checkpoint
    ],
    logger=mlf_logger,
)
trainer.fit(model=model, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# Seed set to 42
# Experiment with name RNAQuANet-lociparse_less_features_dataset__all_tuplet not found. Creating it.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name           | Type                      | Params | Mode
# ----------------------------------------------------------------------
# 0  | norm1          | BatchNorm                 | 122    | train
# 1  | GATconv1       | GATv2Conv                 | 39.0 K | train
# 2  | GATconv2       | GATv2Conv                 | 128 K  | train
# 3  | GATconv3       | GATv2Conv                 | 128 K  | train
# 4  | GCN2Conv1      | GeneralConv               | 32.0 K | train
# 5  | fc1            | Linear                    | 3.8 K  | train
# 6  | fc3            | Linear                    | 62     | train
# 7  | dropout        | Dropout                   | 0      | train
# 8  | activation     | LeakyReLU                 | 0      | train
# 9  | activationlast | ReLU                      | 0      | train
# 10 | aggregation    | SetTransformerAggregation | 61.3 K | train
# ----------------------------------------------------------------------
# 393 K     Trainable params
# 0         Non-trainable params
# 393 K     Total params
# 1.572     Total estimated model params size (MB)
# 52        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6125. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4697. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4342. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3426. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3998. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9326. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 15500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 13058. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2261. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6380. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 13500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 11900. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7835. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5015. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3438. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3114. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7797. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8875. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5641. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4864. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5752. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10875. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4886. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4250. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3242. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4112. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7726. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2875. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8595. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 11055. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 11375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7775. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6875. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6970. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3220. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1902. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4125. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2469. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1875. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2538. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3360. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2314. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2606. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3410. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9443. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6411. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4411. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2825. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5869. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4969. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5134. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9250. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3145. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2311. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5175. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5532. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6370. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 11015. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3875. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3155. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5815. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7823. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3125. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3176. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5250. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2553. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2111. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4065. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 19455. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3368. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2055. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6291. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 13375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9720. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2760. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7417. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4147. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2095. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4710. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5764. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5003. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6660. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8900. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7700. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5860. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2144. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2125. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2457. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3868. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4972. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5125. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4198. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4620. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5481. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4029. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2035. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3181. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3620. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2600. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2062. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5833. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7235. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3527. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6821. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8225. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6325. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2316. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2250. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8064. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6143. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6519. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10143. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4555. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2707. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5375. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7994. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3966. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5718. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 7392. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1710. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 14430. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 18750. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10698. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2470. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 4885. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6099. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5618. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10040. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 17000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 12480. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9447. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9500. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8072. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8000. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 9368. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5358. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# ...
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#       File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#                       File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 217, in _finalize_join
#                                                     thread.join()        thread.join()thread.join()    thread.join()thread.join()    thread.join()thread.join()    thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()thread.join()
# thread.join()
#
# thread.join()
# thread.join()
#
#
# thread.join()
#
#
#
#
#
#
#
#
#
#
#
#
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#   File "/usr/lib/python3.13/threading.py", line 1092, in join
#           File "/usr/lib/python3.13/threading.py", line 1092, in join
#               File "/usr/lib/python3.13/threading.py", line 1092, in join
#                                                         self._handle.join(timeout)            self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)    self._handle.join(timeout)    self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)
# self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)self._handle.join(timeout)
#
#
# self._handle.join(timeout)
# self._handle.join(timeout)
#
#
#
#
#
#
#
#
#
#
#
#
# KeyboardInterrupt
#
#
# KeyboardInterruptKeyboardInterruptKeyboardInterrupt
#
#
# : : : : KeyboardInterruptKeyboardInterruptKeyboardInterrupt: : : : : : : : : : : : : : : :
#
# :
#
# : :
# :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:574, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     568 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     569     self.state.fn,
#     570     ckpt_path,
#     571     model_provided=True,
#     572     model_connected=self.lightning_module is not None,
#     573 )
# --> 574 self._run(model, ckpt_path=ckpt_path)
#     576 assert self.state.stopped
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:981, in Trainer._run(self, model, ckpt_path)
#     978 # ----------------------------
#     979 # RUN THE TRAINER
#     980 # ----------------------------
# --> 981 results = self._run_stage()
#     983 # ----------------------------
#     984 # POST-Training CLEAN UP
#     985 # ----------------------------
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1025, in Trainer._run_stage(self)
#    1024 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025     self.fit_loop.run()
#    1026 return None
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:205, in _FitLoop.run(self)
#     204 self.on_advance_start()
# --> 205 self.advance()
#     206 self.on_advance_end()
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:363, in _FitLoop.advance(self)
#     362 assert self._data_fetcher is not None
# --> 363 self.epoch_loop.run(self._data_fetcher)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/training_epoch_loop.py:140, in _TrainingEpochLoop.run(self, data_fetcher)
#     139 try:
# --> 140     self.advance(data_fetcher)
#     141     self.on_advance_end(data_fetcher)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/training_epoch_loop.py:278, in _TrainingEpochLoop.advance(self, data_fetcher)
#     275 # -----------------------------------------
#     276 # SAVE METRICS TO LOGGERS AND PROGRESS_BAR
#     277 # -----------------------------------------
# --> 278 trainer._logger_connector.update_train_step_metrics()
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:163, in _LoggerConnector.update_train_step_metrics(self)
#     162 if self.should_update_logs or self.trainer.fast_dev_run:
# --> 163     self.log_metrics(self.metrics["log"])
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:117, in _LoggerConnector.log_metrics(self, metrics, step)
#     116 for logger in self.trainer.loggers:
# --> 117     logger.log_metrics(metrics=scalar_metrics, step=step)
#     118     logger.save()
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning_utilities/core/rank_zero.py:42, in rank_zero_only.<locals>.wrapped_fn(*args, **kwargs)
#      41 if rank == 0:
# ---> 42     return fn(*args, **kwargs)
#      43 return default
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/loggers/mlflow.py:270, in MLFlowLogger.log_metrics(self, metrics, step)
#     268     metrics_list.append(Metric(key=k, value=v, timestamp=timestamp_ms, step=step or 0))
# --> 270 self.experiment.log_batch(run_id=self.run_id, metrics=metrics_list, **self._log_batch_kwargs)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:1904, in MlflowClient.log_batch(self, run_id, metrics, params, tags, synchronous)
#    1902 params = [Param(key=param.key, value=str(param.value)) for param in params]
# -> 1904 return self._tracking_client.log_batch(
#    1905     run_id, metrics, params, tags, synchronous=synchronous
#    1906 )
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:762, in TrackingServiceClient.log_batch(self, run_id, metrics, params, tags, synchronous)
#     761 if synchronous:
# --> 762     self.store.log_batch(run_id=run_id, metrics=metrics_batch, params=[], tags=[])
#     763 else:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:539, in RestStore.log_batch(self, run_id, metrics, params, tags)
#     536 req_body = message_to_json(
#     537     LogBatch(metrics=metric_protos, params=param_protos, tags=tag_protos, run_id=run_id)
#     538 )
# --> 539 self._call_endpoint(LogBatch, req_body)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:377, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     376     call_kwargs["json"] = json_body
# --> 377     response = http_request(**call_kwargs)
#     379 response = verify_rest_response(response, endpoint)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:181, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     180 try:
# --> 181     return _get_http_response_with_retries(
#     182         method,
#     183         url,
#     184         max_retries,
#     185         backoff_factor,
#     186         backoff_jitter,
#     187         retry_codes,
#     188         raise_on_status,
#     189         headers=headers,
#     190         verify=host_creds.verify,
#     191         timeout=timeout,
#     192         respect_retry_after_header=respect_retry_after_header,
#     193         **kwargs,
#     194     )
#     195 except requests.exceptions.Timeout as to:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/mlflow/utils/request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /usr/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File /usr/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /usr/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /usr/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File /usr/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /usr/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 71
#      59 model_checkpoint = ModelCheckpoint(monitor="val_loss_mae", save_top_k=1, mode="min")
#      60 trainer = L.Trainer(
#      61     max_epochs=400,
#      62     enable_progress_bar=True,  # callbacks=progress_bar,
#    (...)
#      69     logger=mlf_logger,
#      70 )
# ---> 71 trainer.fit(model=model, train_dataloaders=train_loader, val_dataloaders=val_loader)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:538, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536 self.state.status = TrainerStatus.RUNNING
#     537 self.training = True
# --> 538 call._call_and_handle_interrupt(
#     539     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540 )
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
# Out:
# tensor(1.)

# %%
best_model_path='/home/adamczykb/rnaquanet/checkpoints/RNAQuANet-lociparse_dataset__all/920236849910850327/117a12e5f3ad4fff9c0bc76972c07242/checkpoints/epoch=102-step=34093.ckpt'

# %%
best_model_path='/home/adamczykb/rnaquanet/checkpoints/RNAQuANet-combined_dataset__all/493488456530092571/f8c289b7024c4143ad4856b0ff10284e/checkpoints/epoch=28-step=14355.ckpt'

# %%
model_checkpoint.best_model_path
# Out:
# '/home/adamczykb/rnaquanet/checkpoints/RNAQuANet-lociparse_less_features_dataset__all_tuplet/370595680354796830/76cd101af9b7429aa971c308fc5475d3/checkpoints/epoch=4-step=26505.ckpt'

# %%
import mlflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from rnaquanet.dataset.RNAQuANetDataset import RNAQuANetDataset

dataset_dec_val = DATASET.LOCIPARSE_LESS_FEATURES
dataset_val = RNAQuANetDataset(
    f"/home/adamczykb/rnaquanet/data/06_model_input/{dataset_dec_val.value['path']}/val",
    # subsets=SUBSETS,
    # cutoff=CUTOFF,
)

val_model = RNAQuANet.load_from_checkpoint(
    model_checkpoint.best_model_path,
    number_of_node_features=dataset_val[0].x.shape[1],
    number_of_edge_features=dataset_val[0].edge_attr.shape[1],
    strict=False,
)
val_model = val_model.eval()
res = []
for i in dataset_val:
    res.append(
        [
            i.x.shape[0],
            float(
                abs(
                    i.y.cpu()
                    - val_model(
                        i.x.cuda(),
                        i.edge_index.cuda(),
                        i.edge_attr.cuda(),
                        torch.zeros(i.x.shape[0], dtype=torch.int64).cuda(),
                    )
                    .detach()
                    .cpu()
                    .numpy()
                )
            ),
        ]
    )
df = pd.DataFrame(np.array(res), columns=["length", "error"])
fig, ax = plt.subplots(figsize=(25, 10))

df.boxplot(column="error", by="length", ax=ax)
ax.set_xlabel("structure length")
ax.set_ylabel("error")
ax.set_title("Error distribution by sequence length on validation set")
plt.tight_layout()
mlf_logger.experiment.log_figure(
    mlf_logger.run_id, fig, "error_distribution_by_length.svg"
)
mlf_logger.experiment.log_text(
    mlf_logger.run_id, str(val_model.eval()), "architecture.txt"
)
plt.show()

fig, ax = plt.subplots(figsize=(25, 10))
df.groupby("length").mean().plot(kind="bar", ax=ax)
ax.set_xlabel("structure length")
ax.set_ylabel("mean error")
ax.set_title("Mean error by sequence length on validation set")
mlf_logger.experiment.log_figure(mlf_logger.run_id, fig, "error_mean_by_length.svg")
plt.show()

fig, ax = plt.subplots(figsize=(25, 10))
df.groupby("length").count().plot(kind="bar", ax=ax)

ax.set_xlabel("structure length")
ax.set_ylabel("cardinality")
ax.set_title("Cardinality by sequence length on validation set")
mlf_logger.experiment.log_figure(mlf_logger.run_id, fig, "cardinality_by_length.svg")
plt.show()

mlf_logger.experiment.log_metric(
    mlf_logger.run_id,
    "best_val_loss_mae",
    model_checkpoint.best_model_score.cpu().tolist(),
)
mlf_logger.experiment.log_metric(
    mlf_logger.run_id, "best_val_loss_mse", (df["error"] ** 2.0).mean()
)
# Out:
# The dataset does not contain the 'y' tensor in the data files. Using the 'y' as RMSD.

# %%
model_checkpoint.best_model_path
# Out:
# '/home/adamczykb/rnaquanet/checkpoints/RNAQuANet-lociparse_dataset__all/920236849910850327/333226a0193146909c189016a26e4127/checkpoints/epoch=45-step=15226.ckpt'

# %%
val_model = RNAQuANet.load_from_checkpoint(
'/home/adamczykb/rnaquanet/checkpoints/RNAQuANet-ares_dataset__all/306037256498709437/907d0b5d821048268dfe231227affa42/checkpoints/epoch=11-step=672.ckpt',
    number_of_node_features=dataset_train[0].x.shape[1],strict=False
)
val_model.eval()
val_model._trainer = L.Trainer()
m=torch.jit.script(val_model).cuda()
torch.jit.save(m,f"/tmp/{mlf_logger.run_id}.pt")
mlf_logger.experiment.log_artifact(mlf_logger.run_id,
    f"/tmp/{mlf_logger.run_id}.pt",
    artifact_path="model"
)

mlflow.pytorch.log_model(mlf_logger.run_id, val_model, "models")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[50], line 7
#       5 val_model.eval()
#       6 val_model._trainer = L.Trainer()
# ----> 7 m=torch.jit.script(val_model).cuda()
#       8 torch.jit.save(m,f"/tmp/{mlf_logger.run_id}.pt")
#       9 mlf_logger.experiment.log_artifact(mlf_logger.run_id,
#      10     f"/tmp/{mlf_logger.run_id}.pt",
#      11     artifact_path="model"
#      12 )
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_script.py:1429, in script(obj, optimize, _frames_up, _rcb, example_inputs)
#    1427 prev = _TOPLEVEL
#    1428 _TOPLEVEL = False
# -> 1429 ret = _script_impl(
#    1430     obj=obj,
#    1431     optimize=optimize,
#    1432     _frames_up=_frames_up + 1,
#    1433     _rcb=_rcb,
#    1434     example_inputs=example_inputs,
#    1435 )
#    1437 if prev:
#    1438     log_torchscript_usage("script", model_id=_get_model_id(ret))
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_script.py:1147, in _script_impl(obj, optimize, _frames_up, _rcb, example_inputs)
#    1145 if isinstance(obj, torch.nn.Module):
#    1146     obj = call_prepare_scriptable_func(obj)
# -> 1147     return torch.jit._recursive.create_script_module(
#    1148         obj, torch.jit._recursive.infer_methods_to_compile
#    1149     )
#    1150 else:
#    1151     obj = obj.__prepare_scriptable__() if hasattr(obj, "__prepare_scriptable__") else obj  # type: ignore[operator]
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:557, in create_script_module(nn_module, stubs_fn, share_types, is_tracing)
#     555 if not is_tracing:
#     556     AttributeTypeIsSupportedChecker().check(nn_module)
# --> 557 return create_script_module_impl(nn_module, concrete_type, stubs_fn)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:630, in create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     627     script_module._concrete_type = concrete_type
#     629 # Actually create the ScriptModule, initializing it with the function we just defined
# --> 630 script_module = torch.jit.RecursiveScriptModule._construct(cpp_module, init_fn)
#     632 # Compile methods if necessary
#     633 if concrete_type not in concrete_type_store.methods_compiled:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_script.py:650, in RecursiveScriptModule._construct(cpp_module, init_fn)
#     636 """
#     637 Construct a RecursiveScriptModule that's ready for use.
#     638
#    (...)
#     647     init_fn:  Lambda that initializes the RecursiveScriptModule passed to it.
#     648 """
#     649 script_module = RecursiveScriptModule(cpp_module)
# --> 650 init_fn(script_module)
#     652 # Finalize the ScriptModule: replace the nn.Module state with our
#     653 # custom implementations and flip the _initializing bit.
#     654 RecursiveScriptModule._finalize_scriptmodule(script_module)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:606, in create_script_module_impl.<locals>.init_fn(script_module)
#     603     scripted = orig_value
#     604 else:
#     605     # always reuse the provided stubs_fn to infer the methods to compile
# --> 606     scripted = create_script_module_impl(
#     607         orig_value, sub_concrete_type, stubs_fn
#     608     )
#     610 cpp_module.setattr(name, scripted)
#     611 script_module._modules[name] = scripted
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:634, in create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     632 # Compile methods if necessary
#     633 if concrete_type not in concrete_type_store.methods_compiled:
# --> 634     create_methods_and_properties_from_stubs(
#     635         concrete_type, method_stubs, property_stubs
#     636     )
#     637     # Create hooks after methods to ensure no name collisions between hooks and methods.
#     638     # If done before, hooks can overshadow methods that aren't exported.
#     639     create_hooks_from_stubs(concrete_type, hook_stubs, pre_hook_stubs)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:466, in create_methods_and_properties_from_stubs(concrete_type, method_stubs, property_stubs)
#     463 property_defs = [p.def_ for p in property_stubs]
#     464 property_rcbs = [p.resolution_callback for p in property_stubs]
# --> 466 concrete_type._create_methods_and_properties(
#     467     property_defs, property_rcbs, method_defs, method_rcbs, method_defaults
#     468 )
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:1031, in compile_unbound_method(concrete_type, fn)
#    1029 if _jit_internal.is_ignored_fn(fn):
#    1030     return None
# -> 1031 stub = make_stub(fn, fn.__name__)
#    1032 with torch._jit_internal._disable_emit_hooks():
#    1033     # We don't want to call the hooks here since the graph that is calling
#    1034     # this function is not yet complete
#    1035     create_methods_and_properties_from_stubs(concrete_type, (stub,), ())
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/_recursive.py:71, in make_stub(func, name)
#      69 def make_stub(func, name):
#      70     rcb = _jit_internal.createResolutionCallbackFromClosure(func)
# ---> 71     ast = get_jit_def(func, name, self_name="RecursiveScriptModule")
#      72     return ScriptMethodStub(rcb, ast, func)
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/frontend.py:383, in get_jit_def(fn, def_name, self_name, is_classmethod)
#     380     qualname = get_qualified_name(fn)
#     381     pdt_arg_types = type_trace_db.get_args_types(qualname)
# --> 383 return build_def(
#     384     parsed_def.ctx,
#     385     fn_def,
#     386     type_line,
#     387     def_name,
#     388     self_name=self_name,
#     389     pdt_arg_types=pdt_arg_types,
#     390 )
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/frontend.py:433, in build_def(ctx, py_def, type_line, def_name, self_name, pdt_arg_types)
#     430 body = py_def.body
#     431 r = ctx.make_range(py_def.lineno, py_def.col_offset, py_def.col_offset + len("def"))
# --> 433 param_list = build_param_list(ctx, py_def.args, self_name, pdt_arg_types)
#     434 return_type = None
#     435 if getattr(py_def, "returns", None) is not None:
#
# File ~/rnaquanet/.venv/lib/python3.13/site-packages/torch/jit/frontend.py:459, in build_param_list(ctx, py_args, self_name, pdt_arg_types)
#     455     expr = py_args.kwarg
#     456     ctx_range = ctx.make_range(
#     457         expr.lineno, expr.col_offset - 1, expr.col_offset + len(expr.arg)
#     458     )
# --> 459     raise NotSupportedError(ctx_range, _vararg_kwarg_err)
#     460 if py_args.vararg is not None:
#     461     expr = py_args.vararg
#
# NotSupportedError: Compiled functions can't take variable number of arguments or use keyword-only arguments with defaults:
#   File "/home/adamczykb/rnaquanet/.venv/lib/python3.13/site-packages/torch_geometric/nn/conv/message_passing.py", line 425
#         edge_index: Adj,
#         size: Size = None,
#         **kwargs: Any,
#          ~~~~~~~ <--- HERE
#     ) -> Tensor:
#         r"""The initial call to start propagating messages.

# %%
train_loader = DataLoader(dataset_train, num_workers=24, batch_size=125, shuffle=True)
